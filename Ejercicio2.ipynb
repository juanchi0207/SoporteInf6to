# %% [markdown]
# <a href="https://colab.research.google.com/github/Juanchi0207/SoporteInf6to/blob/main/Ejercicio2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
csv = pd.read_csv("/content/storms.csv", sep = ";")
csvColumnas = list(csv.columns)

# %%
csv = csv[csv['category'].notna()]

# %%
csv['hour'] = csv['hour'].apply(lambda x: str(x) + ':00')

# %%
csv.drop(columns=['Unnamed: 0'], inplace=True)

# %%
csv.index = np.arange(1, len(csv) + 1)

# %%
csv
# Out:
#          name  year  month  day   hour   lat   long     status  category  \
# 1     Blanche  1975      7   27   6:00  35,9    -70  hurricane       1.0
# 2     Blanche  1975      7   27  12:00  36,9    -69  hurricane       1.0
# 3     Blanche  1975      7   27  18:00  37,9    -68  hurricane       1.0
# 4     Blanche  1975      7   28   0:00  39,3  -67,2  hurricane       1.0
# 5     Blanche  1975      7   28   6:00  41,2  -66,4  hurricane       1.0
# ...       ...   ...    ...  ...    ...   ...    ...        ...       ...
# 4680      Sam  2021     10    4   0:00  38,7  -52,2  hurricane       2.0
# 4681      Sam  2021     10    4   6:00  39,9  -49,9  hurricane       2.0
# 4682      Sam  2021     10    4  12:00  41,4  -47,1  hurricane       2.0
# 4683      Sam  2021     10    4  18:00  43,8  -43,6  hurricane       1.0
# 4684      Sam  2021     10    5   0:00  46,5  -40,5  hurricane       1.0
#
#       wind  pressure  tropicalstorm_force_diameter  hurricane_force_diameter
# 1       65       987                           NaN                       NaN
# 2       70       984                           NaN                       NaN
# 3       75       981                           NaN                       NaN
# 4       75       980                           NaN                       NaN
# 5       70       980                           NaN                       NaN
# ...    ...       ...                           ...                       ...
# 4680    90       957                         420.0                     100.0
# 4681    90       957                         440.0                      60.0
# 4682    85       960                         440.0                      60.0
# 4683    80       965                         500.0                      70.0
# 4684    75       965                         570.0                      70.0
#
# [4684 rows x 13 columns]
